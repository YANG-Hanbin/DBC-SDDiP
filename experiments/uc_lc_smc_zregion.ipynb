# %% [markdown]
# # UC z-region experiment (LC/SMC)
# Run `LC+Z1` and `SMC+Z1`, then summarize with existing `Z2` benchmark results.

# %%
using Dates
println("Notebook start time: ", now())
println("Repo root: ", pwd())
# Out:
# Notebook start time: 2026-02-26T16:43:14.126
# Repo root: /Users/aaron/StoCutDyProg/notebooks

# %%
run(`julia --project=. experiments/scuc/run_experiment.jl experiments/scuc/configs/z_region/uc_lc_z1.jl`)

# %%
run(`julia --project=. experiments/scuc/run_experiment.jl experiments/scuc/configs/z_region/uc_smc_z1.jl`)

# %%
run(`julia --project=. experiments/plotting/summarize_uc_z_region.jl`)
